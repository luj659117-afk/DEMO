# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math

# %%
random_torch=torch.randn(4,4)
print(random_torch)
# Out:
# tensor([[ 0.8203, -0.8160, -1.8906,  0.1002],
#         [ 0.1635, -1.9977,  0.9359, -0.9107],
#         [-0.5939,  1.3863,  0.0819, -1.2027],
#         [ 0.1863, -0.8483, -1.2657, -0.1685]])
